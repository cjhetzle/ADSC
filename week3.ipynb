# %% [markdown]
# # Week 3

# %% [markdown]
# ## Scrape Wiki Page

# %% [markdown]
# <strong>-Import packages</strong>

# %%
import pandas as pd
import numpy as np
import requests as rq
from bs4 import BeautifulSoup as bs

print('Imported all packages')
# Out:
# Imported all packages

# %% [markdown]
# ### Scrape the web page's HTML

# %%
# URL To scrape from
URL = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
# Request the raw HTML of the page at the URL
raw_page = rq.get(URL)

# %%
# Convert the raw HTML into a BS Parsable format
soup = bs(raw_page.text)

# %%
# Find the Table elements on the page
soup_table = soup.find_all('tbody')
# Looking at only the first table on the page
# Create a list of all the rows and their values
soup_rows = soup_table[0].find_all('tr')
# Use select to create a list of all Table cells
# On the webpage
soup_select = soup.select('td')
# Strip all of the html off of the values
soup_select[2].text.strip()
len(soup_select)

# %% [markdown]
# ### Convert the list of Table Elements into Nx3 List/DF

# %%
table = []
length = 863
i = 0
while i < length:
    row = []
    for k in range(3):
        if (i < length):
            row.append(
                soup_select[i].text.strip()
            )
            i += 1

    table.append(row)

# %%
df = pd.DataFrame(table)

# %% [markdown]
# ### Change the Column Headers

# %%
df.columns = ['PostalCode', 'Borough', 'Neighborhood']

# %% [markdown]
# ### Clean the DF

# %%
dft = df

# %%
# Replace all 'Not assigned' strings with Numpy.NaN
df = df.replace('Not assigned', np.NaN)
# Fill in the remaining cells that don't have a value
# will a Numpy.NaN
df.fillna(value=pd.np.NaN, inplace=True)
# Drop every row where there is a Np.NaN in the
# Borough column
df.dropna(axis=0, subset=['Borough'], inplace=True)
# Replace all neighborhoods without values with the
# values of the borough that they are in
df['Neighborhood'].fillna(df['Borough'], inplace=True)

# %% [markdown]
# ### Groupby The Postal Code and Concatinate the Neighborhoods

# %%
df = df.groupby(['PostalCode','Borough'])['Neighborhood'].apply(','.join).reset_index()
df
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood
# 0    Rouge,Malvern,Rouge,Malvern,Rouge,Malvern,Roug...
# 1    Highland Creek,Rouge Hill,Port Union,Highland ...
# 2    Guildwood,Morningside,West Hill,Guildwood,Morn...
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6    East Birchmount Park,Ionview,Kennedy Park,East...
# 7    Clairlea,Golden Mile,Oakridge,Clairlea,Golden ...
# 8    Cliffcrest,Cliffside,Scarborough Village West,...
# 9    Birch Cliff,Cliffside West,Birch Cliff,Cliffsi...
# 10   Dorset Park,Scarborough Town Centre,Wexford He...
# 11   Maryvale,Wexford,Maryvale,Wexford,Maryvale,Wex...
# 12                                           Agincourt
# 13   Clarks Corners,Sullivan,Tam O'Shanter,Clarks C...
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18   Fairview,Henry Farm,Oriole,Fairview,Henry Farm...
# 19                                     Bayview Village
# 20   Silver Hills,York Mills,Silver Hills,York Mill...
# 21   Newtonbrook,Willowdale,Newtonbrook,Willowdale,...
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27   Flemingdon Park,Don Mills South,Flemingdon Par...
# 28   Bathurst Manor,Downsview North,Wilson Heights,...
# 29   Northwood Park,York University,Northwood Park,...
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76   Dovercourt Village,Dufferin,Dovercourt Village...
# 77   Little Portugal,Trinity,Little Portugal,Trinit...
# 78   Brockton,Exhibition Place,Parkdale Village,Bro...
# 79   Downsview,North Park,Upwood Park,Downsview,Nor...
# 80   Del Ray,Keelesdale,Mount Dennis,Silverthorn,De...
# 81   The Junction North,Runnymede,The Junction Nort...
# 82   High Park,The Junction South,High Park,The Jun...
# 83   Parkdale,Roncesvalles,Parkdale,Roncesvalles,Pa...
# 84   Runnymede,Swansea,Runnymede,Swansea,Runnymede,...
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88   Humber Bay Shores,Mimico South,New Toronto,Hum...
# 89   Alderwood,Long Branch,Alderwood,Long Branch,Al...
# 90   The Kingsway,Montgomery Road,Old Mill North,Th...
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...
# 92   Kingsway Park South West,Mimico NW,The Queensw...
# 93                                    Islington Avenue
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 96                                       Humber Summit
# 97   Emery,Humberlea,Emery,Humberlea,Emery,Humberle...
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village,Martin Grove Gardens,Richvie...
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)
